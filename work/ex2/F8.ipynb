# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity in ('hospital') and
    poly.name_1 IN ('Saitama') and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    1420169268   None           None             None               None
# 1    1420192453   None           None             None               None
# 2    1420192440   None           None             None               None
# 3    1420201581   None           None             None               None
# 4    1420195856   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 357  1420181871   None           None             None               None
# 358  5119354978   None           None             None               None
# 359  6397725265   None           None              8-1               None
# 360  1420179936   None           None             None               None
# 361  2031605170   None           None             None               None
#
#     admin_level aerialway aeroway   amenity  area barrier bicycle brand  \
# 0          None      None    None  hospital  None    None    None  None
# 1          None      None    None  hospital  None    None    None  None
# 2          None      None    None  hospital  None    None    None  None
# 3          None      None    None  hospital  None    None    None  None
# 4          None      None    None  hospital  None    None    None  None
# ..          ...       ...     ...       ...   ...     ...     ...   ...
# 357        None      None    None  hospital  None    None    None  None
# 358        None      None    None  hospital  None    None    None  None
# 359        None      None    None  hospital  None    None    None  None
# 360        None      None    None  hospital  None    None    None  None
# 361        None      None    None  hospital  None    None    None  None
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 357   None     None     None    None         None    None    None    None
# 358   None     None     None    None         None    None    None    None
# 359   None     None     None    None         None    None    None    None
# 360   None     None     None    None         None    None    None    None
# 361   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 357         None    None  None       None  None             None    None
# 358         None    None  None       None  None             None    None
# 359         None    None  None       None  None             None    None
# 360         None    None  None       None  None             None    None
# 361         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
= L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f7e46ee9c2b95d602b35d600589e206.addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#             var marker_e73e0ce0d9fdd27c6b7043e82b277194 = L.marker(
#                 [35.949062999730515, 139.832806],
#                 {
# }
#             ).addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#         var popup_1a3636f894e8acc652e8f0cf4f179c6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_995fa1ab8d648ca064682c732f712901 = $(`&lt;div id=&quot;html_995fa1ab8d648ca064682c732f712901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;全仁会埼玉筑波病院&lt;/div&gt;`)[0];
#                 popup_1a3636f894e8acc652e8f0cf4f179c6c.setContent(html_995fa1ab8d648ca064682c732f712901);
#
#
#
#         marker_e73e0ce0d9fdd27c6b7043e82b277194.bindPopup(popup_1a3636f894e8acc652e8f0cf4f179c6c)
#         ;
#
#
#
#
#             var marker_69f3bf6d8cb1e0959a8e2a168bef2d1c = L.marker(
#                 [36.15153699975093, 139.668562],
#                 {
# }
#             ).addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#         var popup_2afdf70eaffe98e05ee5ac888067fe84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b425f346b337dabe88f24c0690a55b2 = $(`&lt;div id=&quot;html_1b425f346b337dabe88f24c0690a55b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大久保病院&lt;/div&gt;`)[0];
#                 popup_2afdf70eaffe98e05ee5ac888067fe84.setContent(html_1b425f346b337dabe88f24c0690a55b2);
#
#
#
#         marker_69f3bf6d8cb1e0959a8e2a168bef2d1c.bindPopup(popup_2afdf70eaffe98e05ee5ac888067fe84)
#         ;
#
#
#
#
#             var marker_a7737cc2b90bfcdca4dd5fbaca8b0812 = L.marker(
#                 [36.07457499974303, 139.723255],
#                 {
# }
#             ).addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#         var popup_e9f3bc450838ebb7e50642ef72943360 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0487ac4c70a2e5cd4c5021d512a1bb5 = $(`&lt;div id=&quot;html_b0487ac4c70a2e5cd4c5021d512a1bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;堀中病院&lt;/div&gt;`)[0];
#                 popup_e9f3bc450838ebb7e50642ef72943360.setContent(html_b0487ac4c70a2e5cd4c5021d512a1bb5);
#
#
#
#         marker_a7737cc2b90bfcdca4dd5fbaca8b0812.bindPopup(popup_e9f3bc450838ebb7e50642ef72943360)
#         ;
#
#
#
#
#             var marker_7c7c02d7cb02dbfe5db201609c87bbd2 = L.marker(
#                 [36.12462109974815, 139.6009969],
#                 {
# }
#             ).addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#         var popup_899f67f00d6773f5bb35d1a1f7a88a47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_831a5f2d30f56e6aec85d07923938b7d = $(`&lt;div id=&quot;html_831a5f2d30f56e6aec85d07923938b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;福島病院&lt;/div&gt;`)[0];
#                 popup_899f67f00d6773f5bb35d1a1f7a88a47.setContent(html_831a5f2d30f56e6aec85d07923938b7d);
#
#
#
#         marker_7c7c02d7cb02dbfe5db201609c87bbd2.bindPopup(popup_899f67f00d6773f5bb35d1a1f7a88a47)
#         ;
#
#
#
#
#             var marker_2ba60ed852f3c7e60a2cdab4b9b43c81 = L.marker(
#                 [36.070491999742615, 139.71389499999998],
#                 {
# }
#             ).addTo(map_484bddd27a0195d46403991750a6b11e);
#
#
#         var popup_88c69fdadd989bc32ea3c8d135f59998 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_005a6677519bf5b0205af2df7951ff4c = $(`&lt;div id=&quot;html_005a6677519bf5b0205af2df7951ff4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;慈光会東武丸山病院&lt;/div&gt;`)[0];
#                 popup_88c69fdadd989bc32ea3c8d135f59998.setContent(html_005a6677519bf5b0205af2df7951ff4c);
